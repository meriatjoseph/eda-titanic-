# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
numeric_df=df.select_dtypes(include=['number'])
numeric_df.corr()['tip']
# Out:
# total_bill    0.675734
# tip           1.000000
# size          0.489299
# Name: tip, dtype: float64

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# Numerical columns

# %%
sns.histplot(x='total_bill',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df['total_bill'].skew()
# Out:
# 1.1332130376158205

# %%
sns.histplot(df['tip'],kde='True',bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df['tip'].skew()
# Out:
# 1.4654510370979401

# %%
sns.boxplot(df['tip'])
# Out:
# <Axes: >

# %% [markdown]
# Categorical variables

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# bivariate analysis

# %%
sns.barplot(x='smoker',y='tip',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.boxplot(x='smoker',y='tip',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(x='sex',y='tip',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.scatterplot(x='tip',y='total_bill',hue='sex',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.jointplot(x='tip',y='total_bill',kind='reg',data=df)

# %%
pd.crosstab(df['sex'],df['smoker'],normalize=True)*100
# Out:
# smoker         No        Yes
# sex
# Female  22.131148  13.524590
# Male    39.754098  24.590164

# %%
sns.heatmap(pd.crosstab(df['sex'],df['smoker'],normalize=True)*100)
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %%
pd.crosstab(df['sex'],df['time'],normalize=True)*100
# Out:
# time       Dinner      Lunch
# sex
# Female  21.311475  14.344262
# Male    50.819672  13.524590

# %%
sns.countplot(x='day', hue='sex', data=df, palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# Multivariate analysis

# %%
sns.barplot(x='sex',y='tip',hue='smoker',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.scatterplot(x='day',y='tip',hue='smoker',style='sex',data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
