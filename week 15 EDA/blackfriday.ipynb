# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# 25%              5.000000            9.000000    5866.000000
# 50%              9.000000           14.000000    8062.000000
# 75%             15.000000           16.000000   12073.000000
# max             18.000000           18.000000   23961.000000

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.drop(['User_ID'],axis=1,inplace=True)
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 537572  P00193542      M  36-45          16             C
# 537573  P00111142      M  36-45          16             C
# 537574  P00345942      M  36-45          16             C
# 537575  P00285842      M  36-45          16             C
# 537576  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 11 columns]

# %%
df['Gender']=df['Gender'].map({'F':0,'M':1})
df
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00069042       0   0-17          10             A
# 1       P00248942       0   0-17          10             A
# 2       P00087842       0   0-17          10             A
# 3       P00085442       0   0-17          10             A
# 4       P00285442       1    55+          16             C
# ...           ...     ...    ...         ...           ...
# 537572  P00193542       1  36-45          16             C
# 537573  P00111142       1  36-45          16             C
# 537574  P00345942       1  36-45          16             C
# 537575  P00285842       1  36-45          16             C
# 537576  P00118242       1  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 11 columns]

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3, '36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0    1          10             A
# 1       P00248942       0    1          10             A
# 2       P00087842       0    1          10             A
# 3       P00085442       0    1          10             A
# 4       P00285442       1    7          16             C
# ...           ...     ...  ...         ...           ...
# 537572  P00193542       1    4          16             C
# 537573  P00111142       1    4          16             C
# 537574  P00345942       1    4          16             C
# 537575  P00285842       1    4          16             C
# 537576  P00118242       1    4          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 11 columns]

# %%
df_city=pd.get_dummies(df['City_Category'],prefix='City',drop_first=True)

# %%
df=pd.concat([df,df_city],axis=1)

# %%
df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'City_B',
#        'City_C'],
#       dtype='object')

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0    1          10             A
# 1       P00248942       0    1          10             A
# 2       P00087842       0    1          10             A
# 3       P00085442       0    1          10             A
# 4       P00285442       1    7          16             C
# ...           ...     ...  ...         ...           ...
# 537572  P00193542       1    4          16             C
# 537573  P00111142       1    4          16             C
# 537574  P00345942       1    4          16             C
# 537575  P00285842       1    4          16             C
# 537576  P00118242       1    4          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase  City_B  City_C
# 0                      NaN                 NaN      8370   False   False
# 1                      6.0                14.0     15200   False   False
# 2                      NaN                 NaN      1422   False   False
# 3                     14.0                 NaN      1057   False   False
# 4                      NaN                 NaN      7969   False    True
# ...                    ...                 ...       ...     ...     ...
# 537572                 2.0                 NaN     11664   False    True
# 537573                15.0                16.0     19196   False    True
# 537574                15.0                 NaN      8043   False    True
# 537575                 NaN                 NaN      7172   False    True
# 537576                 8.0                 NaN      6875   False    True
#
# [537577 rows x 13 columns]

# %%
df.drop(['City_Category'],axis=1,inplace=True)
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       0    1          10                          2
# 1       P00248942       0    1          10                          2
# 2       P00087842       0    1          10                          2
# 3       P00085442       0    1          10                          2
# 4       P00285442       1    7          16                         4+
# ...           ...     ...  ...         ...                        ...
# 537572  P00193542       1    4          16                          1
# 537573  P00111142       1    4          16                          1
# 537574  P00345942       1    4          16                          1
# 537575  P00285842       1    4          16                          1
# 537576  P00118242       1    4          16                          1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# 1                    0                   1                 6.0
# 2                    0                  12                 NaN
# 3                    0                  12                14.0
# 4                    0                   8                 NaN
# ...                ...                 ...                 ...
# 537572               0                   1                 2.0
# 537573               0                   1                15.0
# 537574               0                   8                15.0
# 537575               0                   5                 NaN
# 537576               0                   5                 8.0
#
#         Product_Category_3  Purchase  City_B  City_C
# 0                      NaN      8370   False   False
# 1                     14.0     15200   False   False
# 2                      NaN      1422   False   False
# 3                      NaN      1057   False   False
# 4                      NaN      7969   False    True
# ...                    ...       ...     ...     ...
# 537572                 NaN     11664   False    True
# 537573                16.0     19196   False    True
# 537574                 NaN      8043   False    True
# 537575                 NaN      7172   False    True
# 537576                 NaN      6875   False    True
#
# [537577 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# City_B                             0
# City_C                             0
# dtype: int64

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.shape
# Out:
# (537577, 12)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042       0    1          10                          2
# 1       P00248942       0    1          10                          2
# 2       P00087842       0    1          10                          2
# 3       P00085442       0    1          10                          2
# 4       P00285442       1    7          16                          4
# ...           ...     ...  ...         ...                        ...
# 537572  P00193542       1    4          16                          1
# 537573  P00111142       1    4          16                          1
# 537574  P00345942       1    4          16                          1
# 537575  P00285842       1    4          16                          1
# 537576  P00118242       1    4          16                          1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 8.0
# 1                    0                   1                 6.0
# 2                    0                  12                 8.0
# 3                    0                  12                14.0
# 4                    0                   8                 8.0
# ...                ...                 ...                 ...
# 537572               0                   1                 2.0
# 537573               0                   1                15.0
# 537574               0                   8                15.0
# 537575               0                   5                 8.0
# 537576               0                   5                 8.0
#
#         Product_Category_3  Purchase  City_B  City_C
# 0                     16.0      8370   False   False
# 1                     14.0     15200   False   False
# 2                     16.0      1422   False   False
# 3                     16.0      1057   False   False
# 4                     16.0      7969   False    True
# ...                    ...       ...     ...     ...
# 537572                16.0     11664   False    True
# 537573                16.0     19196   False    True
# 537574                16.0      8043   False    True
# 537575                16.0      7172   False    True
# 537576                16.0      6875   False    True
#
# [537577 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  537577 non-null  object
#  1   Gender                      537577 non-null  int64
#  2   Age                         537577 non-null  int64
#  3   Occupation                  537577 non-null  int64
#  4   Stay_In_Current_City_Years  537577 non-null  object
#  5   Marital_Status              537577 non-null  int64
#  6   Product_Category_1          537577 non-null  int64
#  7   Product_Category_2          537577 non-null  float64
#  8   Product_Category_3          537577 non-null  float64
#  9   Purchase                    537577 non-null  int64
#  10  City_B                      537577 non-null  bool
#  11  City_C                      537577 non-null  bool
# dtypes: bool(2), float64(2), int64(6), object(2)
# memory usage: 42.0+ MB

# %% [markdown]
# converting object into integers

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  537577 non-null  object
#  1   Gender                      537577 non-null  int64
#  2   Age                         537577 non-null  int64
#  3   Occupation                  537577 non-null  int64
#  4   Stay_In_Current_City_Years  537577 non-null  int32
#  5   Marital_Status              537577 non-null  int64
#  6   Product_Category_1          537577 non-null  int64
#  7   Product_Category_2          537577 non-null  float64
#  8   Product_Category_3          537577 non-null  float64
#  9   Purchase                    537577 non-null  int64
#  10  City_B                      537577 non-null  bool
#  11  City_C                      537577 non-null  bool
# dtypes: bool(2), float64(2), int32(1), int64(6), object(1)
# memory usage: 40.0+ MB

# %%
sns.barplot(x='Age',y='Purchase',hue='Gender',data=df)
plt.show()

# %% [markdown]
# purchasing of men is higher than women

# %%
# visulalisation of purchgase with occupation
sns.barplot(x='Occupation',y='Purchase',hue='Gender',data=df)
plt.show()

# %%
sns.barplot(x='Product_Category_1', y='Purchase', hue='Gender', data=df)
plt.show()

# %%
sns.barplot(x='Product_Category_2', y='Purchase', hue='Gender', data=df)
plt.show()

# %%
sns.barplot(x='Product_Category_3', y='Purchase', hue='Gender', data=df)
plt.show()

# %% [markdown]
# product 1 is mostly purchased

# %% [markdown]
# # feature scaling

# %%
x=df.drop(['Purchase'],axis=1)
x
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0            0    1          10                           2               0
# 1            0    1          10                           2               0
# 2            0    1          10                           2               0
# 3            0    1          10                           2               0
# 4            1    7          16                           4               0
# ...        ...  ...         ...                         ...             ...
# 537572       1    4          16                           1               0
# 537573       1    4          16                           1               0
# 537574       1    4          16                           1               0
# 537575       1    4          16                           1               0
# 537576       1    4          16                           1               0
#
#         Product_Category_1  Product_Category_2  Product_Category_3  City_B  \
# 0                        3                 8.0                16.0   False
# 1                        1                 6.0                14.0   False
# 2                       12                 8.0                16.0   False
# 3                       12                14.0                16.0   False
# 4                        8                 8.0                16.0   False
# ...                    ...                 ...                 ...     ...
# 537572                   1                 2.0                16.0   False
# 537573                   1                15.0                16.0   False
# 537574                   8                15.0                16.0   False
# 537575                   5                 8.0                16.0   False
# 537576                   5                 8.0                16.0   False
#
#         City_C
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# ...        ...
# 537572    True
# 537573    True
# 537574    True
# 537575    True
# 537576    True
#
# [537577 rows x 10 columns]

# %%
y=df['Purchase']
y
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
#           ...
# 537572    11664
# 537573    19196
# 537574     8043
# 537575     7172
# 537576     6875
# Name: Purchase, Length: 537577, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[291], line 1
# ----> 1 df.drop(['Product_ID'],axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Product_ID'] not found in axis"

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# # train your model
